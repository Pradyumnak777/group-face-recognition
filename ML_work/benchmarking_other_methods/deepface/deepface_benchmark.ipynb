# %%
import sys
sys.path.insert(0, '/data/facebiometrics/attendance_app/ML_work/other_methods_installed/deepface/')

from deepface import DeepFace
# Out:
# 2025-01-01 10:00:09.674736: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib.pyplot as plt

# %%
img1 = "/data/facebiometrics/attendance_app/ML_work/modified_lfw_datasets/embedding_lfw/Adrien_Brody/Adrien_Brody_0.jpg"
img2 = "/data/facebiometrics/attendance_app/ML_work/modified_lfw_datasets/embedding_lfw/Adrien_Brody/Adrien_Brody_1.jpg"

# %%
result = DeepFace.verify(
  img1_path = "/data/facebiometrics/attendance_app/ML_work/modified_lfw_datasets/embedding_lfw/Adrien_Brody/Adrien_Brody_0.jpg",
  img2_path = "/data/facebiometrics/attendance_app/ML_work/modified_lfw_datasets/embedding_lfw/Adrien_Brody/Adrien_Brody_1.jpg",
  model_name = 'ArcFace'
)
# Out:
# W0000 00:00:1731234585.653002  673586 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 24-11-10 15:59:47 - 🔗 arcface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5 to /data/facebiometrics/.deepface/weights/arcface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /data/facebiometrics/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:12<00:00, 11.2MB/s]

# %%
print(result)
# Out:
# {'verified': True, 'distance': 0.579645, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 77, 'y': 66, 'w': 118, 'h': 118, 'left_eye': None, 'right_eye': None}, 'img2': {'x': 61, 'y': 67, 'w': 121, 'h': 121, 'left_eye': None, 'right_eye': None}}, 'time': 17.52}

# %%
faces = DeepFace.extract_faces(img_path='/data/facebiometrics/attendance_app/ML_work/group_image_44.jpg')

# if faces detected
if faces:
    fig, axes = plt.subplots(1, len(faces), figsize=(15, 5))
    if len(faces) == 1:
        axes = [axes]

    # show all faces
    for i, face_obj in enumerate(faces):
        face_img = face_obj["face"]
        axes[i].imshow(face_img)
        axes[i].axis("off")
        axes[i].set_title(f"Face {i + 1}")

    plt.show()
else:
    print("No faces detected")

# %%
#code in deepface()
